# %% [markdown]
# <a href="https://colab.research.google.com/github/daFumi/Testing_Repository/blob/main/lr3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Скопированная таблица с сайта https://www.kommersant.ru/doc/2645543
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
df=pd.read_csv('energy.csv')
df = df.dropna()
df
# Out:
#                    ТЭС              Владелец                Регион  \
# 0    Сургутская ГРЭС-2           Э.Он Россия   Ханты-Мансийский АО
# 1      Рефтинская ГРЭС           Энел Россия  Свердловская область
# 2     Костромская ГРЭС             Интер РАО   Костромская область
# 3    Сургутская ГРЭС-1  Газпромэнергохолдинг   Ханты-Мансийский АО
# 4       Рязанская ГРЭС  Газпромэнергохолдинг     Рязанская область
# 5       Киришская ГРЭС  Газпромэнергохолдинг  Ленинградскаяобласть
# 6     Конаковская ГРЭС           Энел Россия      Тверская область
# 7     Ириклинская ГРЭС             Интер РАО  Оренбургская область
# 8        Пермская ГРЭС             Интер РАО         Пермский край
# 9  Ставропольская ГРЭС  Газпромэнергохолдинг   Ставропольский край
#
#    Мощность (ГВт)
# 0             5.6
# 1             3.8
# 2             3.6
# 3             3.3
# 4             3.3
# 5             2.6
# 6             2.5
# 7             2.4
# 8             2.4
# 9             2.4

# %%
#4.1. Сортировка данных
sorted_df = df.sort_values(by='ТЭС', ascending=True) #сортировка по Алфавиту столбца ТЭС
sorted_df
# Out:
#                    ТЭС              Владелец                Регион  \
# 7     Ириклинская ГРЭС             Интер РАО  Оренбургская область
# 5       Киришская ГРЭС  Газпромэнергохолдинг  Ленинградскаяобласть
# 6     Конаковская ГРЭС           Энел Россия      Тверская область
# 2     Костромская ГРЭС             Интер РАО   Костромская область
# 8        Пермская ГРЭС             Интер РАО         Пермский край
# 1      Рефтинская ГРЭС           Энел Россия  Свердловская область
# 4       Рязанская ГРЭС  Газпромэнергохолдинг     Рязанская область
# 9  Ставропольская ГРЭС  Газпромэнергохолдинг   Ставропольский край
# 3    Сургутская ГРЭС-1  Газпромэнергохолдинг   Ханты-Мансийский АО
# 0    Сургутская ГРЭС-2           Э.Он Россия   Ханты-Мансийский АО
#
#    Мощность (ГВт)
# 7             2.4
# 5             2.6
# 6             2.5
# 2             3.6
# 8             2.4
# 1             3.8
# 4             3.3
# 9             2.4
# 3             3.3
# 0             5.6

# %%
#4.2. Добавление к таблице столбца с новыми данными, полученным путем преобразований имеющихся.
mosh = df['Мощность (ГВт)'].mean()
df1 = df.assign(Отклонение_отсреднего=df['Мощность (ГВт)'] - mosh)
df1
# Out:
#                    ТЭС              Владелец                Регион  \
# 0    Сургутская ГРЭС-2           Э.Он Россия   Ханты-Мансийский АО
# 1      Рефтинская ГРЭС           Энел Россия  Свердловская область
# 2     Костромская ГРЭС             Интер РАО   Костромская область
# 3    Сургутская ГРЭС-1  Газпромэнергохолдинг   Ханты-Мансийский АО
# 4       Рязанская ГРЭС  Газпромэнергохолдинг     Рязанская область
# 5       Киришская ГРЭС  Газпромэнергохолдинг  Ленинградскаяобласть
# 6     Конаковская ГРЭС           Энел Россия      Тверская область
# 7     Ириклинская ГРЭС             Интер РАО  Оренбургская область
# 8        Пермская ГРЭС             Интер РАО         Пермский край
# 9  Ставропольская ГРЭС  Газпромэнергохолдинг   Ставропольский край
#
#    Мощность (ГВт)  Отклонение_отсреднего
# 0             5.6                   2.41
# 1             3.8                   0.61
# 2             3.6                   0.41
# 3             3.3                   0.11
# 4             3.3                   0.11
# 5             2.6                  -0.59
# 6             2.5                  -0.69
# 7             2.4                  -0.79
# 8             2.4                  -0.79
# 9             2.4                  -0.79

# %%
#4.3. Выбор фрагмента таблицы по условию.
#1 способ
condition = df['Мощность (ГВт)'] > 3
filtered_df = df[condition]
filtered_df
# Out:
#                  ТЭС              Владелец                Регион  \
# 0  Сургутская ГРЭС-2           Э.Он Россия   Ханты-Мансийский АО
# 1    Рефтинская ГРЭС           Энел Россия  Свердловская область
# 2   Костромская ГРЭС             Интер РАО   Костромская область
# 3  Сургутская ГРЭС-1  Газпромэнергохолдинг   Ханты-Мансийский АО
# 4     Рязанская ГРЭС  Газпромэнергохолдинг     Рязанская область
#
#    Мощность (ГВт)
# 0             5.6
# 1             3.8
# 2             3.6
# 3             3.3
# 4             3.3

# %%
#2 способ
filtered1_df = df.loc[df['Мощность (ГВт)'] > 4]
filtered1_df
# Out:
#                  ТЭС     Владелец               Регион  Мощность (ГВт)
# 0  Сургутская ГРЭС-2  Э.Он Россия  Ханты-Мансийский АО             5.6

# %%
#4.4. Выбор фрагмента таблицы по номерам строк и столбцов.
filtered_df = df.iloc[[0, 1, 2], [0, 1]] # Выберите строки с индексами 0, 1 и 2, а также столбцы с индексами 0 и 1
filtered_df

# %%
#4.5 Расчеты статистических показателей по сгруппированным данным.
total_sales_by_category = df.groupby('Владелец')['Мощность (ГВт)'].sum()
print(total_sales_by_category)

# %%
#4.6. Построение гистограммы по данным.
plt.bar(df['ТЭС'], df['Мощность (ГВт)'])
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(0.5))
plt.xticks(rotation=90)
plt.xlabel('ТЭС')
plt.ylabel('Мощность (ГВт)')
plt.title('Гистограмма мощности ТЭС')

plt.show()

# %%
#4.7. Построение круговой диаграммы по данным.
plt.pie(df['Мощность (ГВт)'], labels=df['ТЭС'])
plt.title('Круговая диаграмма мощности ТЭС')
plt.show()

# %%
#4.8. Построение интерактивного графика по данным.
fig = px.bar(df, x='ТЭС', y='Мощность (ГВт)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b2721de8-c0dd-4303-95d4-84dddcdd4856" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2721de8-c0dd-4303-95d4-84dddcdd4856")) {                    Plotly.newPlot(                        "b2721de8-c0dd-4303-95d4-84dddcdd4856",                        [{"alignmentgroup":"True","hovertemplate":"\u0422\u042d\u0421=%{x}<br>\u041c\u043e\u0449\u043d\u043e\u0441\u0442\u044c (\u0413\u0412\u0442)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["\u0421\u0443\u0440\u0433\u0443\u0442\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421-2","\u0420\u0435\u0444\u0442\u0438\u043d\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421","\u041a\u043e\u0441\u0442\u0440\u043e\u043c\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421","\u0421\u0443\u0440\u0433\u0443\u0442\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421-1","\u0420\u044f\u0437\u0430\u043d\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421","\u041a\u0438\u0440\u0438\u0448\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421","\u041a\u043e\u043d\u0430\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421","\u0418\u0440\u0438\u043a\u043b\u0438\u043d\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421","\u041f\u0435\u0440\u043c\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421","\u0421\u0442\u0430\u0432\u0440\u043e\u043f\u043e\u043b\u044c\u0441\u043a\u0430\u044f \u0413\u0420\u042d\u0421"],"xaxis":"x","y":[5.6,3.8,3.6,3.3,3.3,2.6,2.5,2.4,2.4,2.4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":"" ...
